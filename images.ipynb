# %% [markdown]
# <a href="https://colab.research.google.com/github/fhdbbk/learning_tf2/blob/master/images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load images

# %% [markdown]
# This tutorial provides a simple example of how to load an image dataset using `tf.data`.
#
# The dataset used in this example is distributed as directories of images, with one class of image per directory.

# %%
# !nvidia-smi --query-gpu=name --format=csv,noheader
# Out:
# Tesla T4

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
print(AUTOTUNE)
# Out:
# -1

# %%
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# ### Retrieve the images
#
# Before you start any training, you will need a set of images to teach the network about the new classes you want to recognize. You can use an archive of creative-commons licensed flower photos from Google.
#
# Note: all images are licensed CC-BY, creators are listed in the `LICENSE.txt` file.

# %%
import pathlib
data_dir = tf.keras.utils.get_file(origin='https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
                                         fname='flower_photos', untar=True)
print(data_dir)
print(type(data_dir))
data_dir = pathlib.Path(data_dir)
print(data_dir)
print(type(data_dir))
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 2s 0us/step
# /root/.keras/datasets/flower_photos
# <class 'str'>
# /root/.keras/datasets/flower_photos
# <class 'pathlib.PosixPath'>

# %%
# !ls {str(data_dir)}
# Out:
# daisy  dandelion  LICENSE.txt  roses  sunflowers  tulips

# %% [markdown]
# After downloading (218MB), you should now have a copy of the flower photos available.
#
# The directory contains 5 sub-directories, one per class:

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 3670

# %%
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"])
CLASS_NAMES
# Out:
# array(['sunflowers', 'dandelion', 'roses', 'tulips', 'daisy'],
#       dtype='<U10')

# %% [markdown]
# Each directory contains images of that type of flower. Here are some roses:

# %%
roses = list(data_dir.glob('roses/*'))

for image_path in roses[:3]:
    display.display(Image.open(str(image_path)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x7FC18AC69E48>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240 at 0x7FC18AF29CC0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=175x240 at 0x7FC18AF29CF8>

# %% [markdown]
# ## Load using `keras.preprocessing`

# %% [markdown]
# A simple way to load images is to use `tf.keras.preprocessing`.

# %%
# The 1./255 is to convert from uint8 to float32 in range [0,1].
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Define some parameters for the loader:

# %%
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)
print("Steps per epoch: {}".format(STEPS_PER_EPOCH))
# Out:
# Steps per epoch: 115.0

# %%
train_data_gen = image_generator.flow_from_directory(directory=str(data_dir),
                                                     batch_size=BATCH_SIZE,
                                                     shuffle=True,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                     classes = list(CLASS_NAMES))
# Out:
# Found 3670 images belonging to 5 classes.

# %% [markdown]
# Inspect a batch:

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
      plt.axis('off')

# %%
image_batch, label_batch = next(train_data_gen)

# %%
label_batch[:2]
# Out:
# array([[0., 0., 1., 0., 0.],
#        [0., 0., 0., 0., 1.]], dtype=float32)

# %%
CLASS_NAMES[label_batch[0] == 1][0].title()
# Out:
# 'Roses'

# %%
show_batch(image_batch, label_batch)

# %% [markdown]
# ## Load using `tf.data`

# %% [markdown]
# The above `keras.preprocessing` method is convienient, but has three downsides:
#
# 1. It's slow. See the performance section below.
# 1. It lacks fine-grained control.
# 1. It is not well integrated with the rest of TensorFlow.

# %% [markdown]
# To load the files as a `tf.data.Dataset` first create a dataset of the file paths:

# %%
str(data_dir/'*/*')
# Out:
# '/root/.keras/datasets/flower_photos/*/*'

# %%
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*'))
print(list_ds)
# Out:
# <ShuffleDataset shapes: (), types: tf.string>

# %%
for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'/root/.keras/datasets/flower_photos/sunflowers/2803725948_5fd1f2fc99_n.jpg'
# b'/root/.keras/datasets/flower_photos/dandelion/3198028825_fdfaa1d020.jpg'
# b'/root/.keras/datasets/flower_photos/roses/18760363474_a707331322_n.jpg'
# b'/root/.keras/datasets/flower_photos/roses/4279989256_9a48c0d194_n.jpg'
# b'/root/.keras/datasets/flower_photos/tulips/6934951920_d43ff8b78d.jpg'

# %% [markdown]
# Write a short pure-tensorflow function that converts a file path to an `(img, label)` pair:

# %%
a = np.array([1, 2, 3, 4, 5, 2])
b = 2
print(b == a)
# Out:
# [False  True False False False  True]

# %%
f_name = list_ds.take(1)
print(list(f_name)[0].numpy())
for n in f_name:
  parts = tf.strings.split(n, os.path.sep)
  print(parts)
  print(parts[-2])
  print(parts[-2] == CLASS_NAMES)
  print(CLASS_NAMES)
# Out:
# b'/root/.keras/datasets/flower_photos/daisy/5623010186_796ca8d29a.jpg'
# tf.Tensor(
# [b'' b'root' b'.keras' b'datasets' b'flower_photos' b'tulips'
#  b'13926327692_a07357ff0d.jpg'], shape=(7,), dtype=string)
# tf.Tensor(b'tulips', shape=(), dtype=string)
# tf.Tensor([False False False  True False], shape=(5,), dtype=bool)
# ['sunflowers' 'dandelion' 'roses' 'tulips' 'daisy']

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == CLASS_NAMES

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# Use `Dataset.map` to create a dataset of `image, label` pairs:

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
labeled_ds = list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in labeled_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (224, 224, 3)
# Label:  [False False False  True False]

# %% [markdown]
# ### Basic methods for training

# %% [markdown]
# To train a model with this dataset you will want the data:
#
# * To be well shuffled.
# * To be batched.
# * Batches to be available as soon as possible.
#
# These features can be easily added using the `tf.data` api.

# %%
ex = tf.data.Dataset.from_tensor_slices([1, 2, 3])
ex = ex.repeat()
# print(list(ex.as_numpy_iterator()))

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()

  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  # Repeat forever
  ds = ds.repeat()

  ds = ds.batch(BATCH_SIZE)

  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=AUTOTUNE)

  return ds

# %%
train_ds = prepare_for_training(labeled_ds)

image_batch, label_batch = next(iter(train_ds))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # tf.keras.utils.Sequence

# %%
def get_label_conventional(file_path):
  # convert the path to a list of path components
  parts = str(file_path).split(os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == CLASS_NAMES

# %%
def decode_img_conventional(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.keras.preprocessing.image.load_img(img, color_mode='rgb', target_size=[IMG_HEIGHT, IMG_WIDTH])
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = np.array(img).astype('float')
  img = img / 255.0
  # resize the image to the desired size.
  return img

# %%
def process_path_conventional(file_path):
  label = get_label_conventional(file_path)
  img = decode_img_conventional(str(file_path))
  return img, label

# %%
data = list(data_dir.glob('*/*.jpg'))[:32]
image_batch = []
label_batch = []
for fp in data:
  img, lbl = process_path_conventional(fp)
  image_batch.append(img)
  label_batch.append(lbl)
show_batch(image_batch, label_batch)

# %%
print(get_label_conventional('/keras/st/xyz/roses/adjjye.jpg'))
# Out:
# [False False  True False False]

# %%
from tensorflow.python.keras.utils.data_utils import Sequence
import random

# %%
class DataGenerator(Sequence):
    def __init__(self, x_set, batch_size, shuffle=False):
        self.x = x_set
        self.batch_size = batch_size
        self.shuffle = shuffle
        if shuffle:
          self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __iter__(self):
      for item in (self[i] for i in range(len(self))):
        yield item

    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.x) 

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
                
        images = []
        labels = []
        for fp in batch_x:
          img, lbl = process_path_conventional(fp)
          images.append(img)
          labels.append(lbl)
            
        return images, labels

# %%
train_data_seq = DataGenerator(list(data_dir.glob('*/*.jpg')), 32, shuffle=True)

# %%
imgs, lbls = next(iter(train_data_seq))
show_batch(imgs, lbls)

# %% [markdown]
# ## Performance
#
# Note: This section just shows a couple of easy tricks that may help performance. For an in depth guide see [Input Pipeline Performance](../../guide/performance/datasets).

# %% [markdown]
# To investigate, first here's a function to check the performance of our datasets:

# %%
import time
default_timeit_steps = 1000

def timeit(ds, steps=default_timeit_steps):
  start = time.time()
  it = iter(ds)
  for i in range(steps):
    try:
      batch = next(it)
    except StopIteration:
      it = iter(ds)
    if i%10 == 0:
      print('.',end='')
  print()
  end = time.time()

  duration = end-start
  print("{} batches: {} s".format(steps, duration))
  print("{:0.5f} Images/s".format(BATCH_SIZE*steps/duration))

# %% [markdown]
# Let's compare the speed of the two data generators:

# %%
# `keras.preprocessing`
timeit(train_data_gen)
# Out:
# ....................................................................................................
# 1000 batches: 86.95809245109558 s
# 367.99335 Images/s

# %%
# `sequence'
timeit(train_data_seq)
# Out:
# ....................................................................................................
# 1000 batches: 90.06883001327515 s
# 355.28384 Images/s

# %%
# `tf.data`
timeit(train_ds)
# Out:
# ....................................................................................................
# 1000 batches: 12.790901899337769 s
# 2501.77824 Images/s

# %% [markdown]
# A large part of the performance gain comes from the use of `.cache`.

# %%
uncached_ds = prepare_for_training(labeled_ds, cache=False)
timeit(uncached_ds)
# Out:
# ....................................................................................................
# 1000 batches: 60.8965425491333 s
# 525.48139 Images/s

# %% [markdown]
# If the dataset doesn't fit in memory use a cache file to maintain some of the advantages:

# %%
filecache_ds = prepare_for_training(labeled_ds, cache="./flowers.tfcache")
timeit(filecache_ds)
# Out:
# ....................................................................................................
# 1000 batches: 38.90138626098633 s
# 822.59279 Images/s
